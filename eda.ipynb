# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
df = pd.read_csv('../1_Data/datasets/from2018.csv', index_col='Date').drop('Unnamed: 0', axis=1)
df.index = pd.DatetimeIndex(df.index).to_period('H')
df
# Out:
#                   Hr_End  DA_Demand  RT_Demand  DA_LMP   DA_EC  DA_CC  DA_MLC  \
# Date
# 2018-01-01 01:00       1    14147.2  15521.098  126.32  124.97    0.0    1.35
# 2018-01-02 00:00      24    14665.6  15625.565  158.74  156.84    0.0    1.90
# 2018-01-01 23:00      23    15545.0  16639.854  160.17  158.15    0.0    2.02
# 2018-01-01 22:00      22    16732.8  17873.268  166.82  165.06    0.0    1.76
# 2018-01-01 21:00      21    17832.4  18811.864  167.30  165.24    0.0    2.06
# ...                  ...        ...        ...     ...     ...    ...     ...
# 2022-12-31 02:00       2     9518.3  10151.788   34.20   34.14    0.0    0.06
# 2022-12-31 01:00       1     9982.9  10543.677   38.70   38.66    0.0    0.04
# 2022-12-31 23:00      23    10394.4  11381.525   38.65   38.69    0.0   -0.04
# 2022-12-31 11:00      11    12250.6  12738.467   41.42   41.42    0.0    0.00
# 2023-01-01 00:00      24     9906.5  10832.051   38.95   38.95    0.0    0.00
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 43824 entries, 2018-01-02 00:00 to 2022-12-31 18:00
# Freq: H
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Hr_End              43824 non-null  int64
#  1   DA_Demand           43824 non-null  float64
#  2   RT_Demand           43824 non-null  float64
#  3   DA_LMP              43824 non-null  float64
#  4   DA_EC               43824 non-null  float64
#  5   DA_CC               43824 non-null  float64
#  6   DA_MLC              43824 non-null  float64
#  7   RT_LMP              43824 non-null  float64
#  8   RT_EC               43824 non-null  float64
#  9   RT_CC               43824 non-null  float64
#  10  RT_MLC              43824 non-null  float64
#  11  Dry_Bulb            43824 non-null  int64
#  12  Dew_Point           43824 non-null  int64
#  13  System_Load         43824 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Hr_End                0
# DA_Demand             0
# RT_Demand             0
# DA_LMP                0
# DA_EC                 0
# DA_CC                 0
# DA_MLC                0
# RT_LMP                0
# RT_EC                 0
# RT_CC                 0
# RT_MLC                0
# Dry_Bulb              0
# Dew_Point             0
# System_Load           0
# Reg_Service_Price     0
# Reg_Capacity_Price    0
# Min_5min_RSP          0
# Max_5min_RSP          0
# Min_5min_RCP          0
# Max_5min_RCP          0
# month                 0
# year                  0
# dtype: int64

# %% [markdown]
# # No null values

# %%
df.describe()
# Out:
#              Hr_End     DA_Demand    RT_Demand        DA_LMP         DA_EC  \
# count  43824.000000  43824.000000  43824.00000  43824.000000  43824.000000
# mean      12.500000  13062.997343  13405.39337     46.016609     45.894802
# std        6.922266   2638.187093   2702.64419     36.920201     36.729426
# min        1.000000   7407.700000   8234.88400      1.760000      1.760000
# 25%        6.750000  11180.425000  11486.13750     23.020000     22.990000
# 50%       12.500000  12739.700000  13134.55500     33.790000     33.765000
# 75%       18.250000  14544.900000  14933.37225     56.020000     55.872500
# max       24.000000  25352.700000  25612.17500    374.980000    373.150000
#
#               DA_CC        DA_MLC        RT_LMP         RT_EC         RT_CC  \
# count  43824.000000  43824.000000  43824.000000  43824.000000  43824.000000
# mean      -0.018066      0.139874     45.458822     45.259652      0.075090
# ...

# %%
# 0 Demand?

m = df['RT_Demand'] == 0
df[m]
# Out:
# Empty DataFrame
# Columns: [Hr_End, DA_Demand, RT_Demand, DA_LMP, DA_EC, DA_CC, DA_MLC, RT_LMP, RT_EC, RT_CC, RT_MLC, Dry_Bulb, Dew_Point, System_Load, Reg_Service_Price, Reg_Capacity_Price, Min_5min_RSP, Max_5min_RSP, Min_5min_RCP, Max_5min_RCP]
# Index: []

# %%
# 0 Demand?

m = df['RT_LMP'] == 0
df[m]
# Out:
#                   Hr_End  DA_Demand  RT_Demand  DA_LMP  DA_EC  DA_CC  DA_MLC  \
# Date
# 2018-03-04 09:00       9    12197.3  12189.470   19.57  19.45   0.00    0.12
# 2018-04-22 09:00       9    10683.5  10773.595   26.28  26.35   0.00   -0.07
# 2019-01-30 15:00      15    15370.2  15149.447   89.58  88.84   0.04    0.70
# 2019-02-16 14:00      14    12583.5  12288.348   25.78  25.75   0.01    0.02
# 2020-03-21 00:00      24     9469.1  10340.682   11.61  11.51   0.05    0.05
# 2020-11-29 02:00       2     9174.1  10068.166   12.75  12.69   0.00    0.06
# 2022-12-04 04:00       4     9776.9  10035.652   30.09  29.62   0.18    0.29
#
#                   RT_LMP  RT_EC  RT_CC  RT_MLC  Dry_Bulb  Dew_Point  \
# Date
# 2018-03-04 09:00     0.0  -0.02   0.02     0.0        38         25
# 2018-04-22 09:00     0.0   0.00   0.00     0.0        44         22
# 2019-01-30 15:00     0.0   0.00   0.00     0.0        28          5
# ...

# %%
fig, ax = plt.subplots(figsize=(18, 7))
sns.boxplot(data=df, ax=ax)
ax.tick_params(axis='x', rotation=45)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:470: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]

# %% [markdown]
# # Correlation

# %%
sns.set_theme(style="white")


corr = df.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))


fig, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 130, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)
# Out:
# <AxesSubplot: >

# %%
df['month'] = df.index.month
df['year'] = df.index.year
sns.lineplot(x='month',y='RT_Demand', hue='year',data=df.query('year<2023'), palette='tab10')
# Out:
# <AxesSubplot: xlabel='month', ylabel='RT_Demand'>

# %%
df['month'] = df.index.month
df['year'] = df.index.year
sns.lineplot(x='month',y='RT_LMP', hue='year',data=df.query('year<2023'), palette='tab10')
# Out:
# <AxesSubplot: xlabel='month', ylabel='RT_LMP'>

# %%
sns.scatterplot(x=df['RT_Demand'], y=df['RT_LMP'])
# Out:
# <AxesSubplot: xlabel='RT_Demand', ylabel='RT_LMP'>

# %%
sns.boxplot(df[['Dry_Bulb', 'Dew_Point']])
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:470: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
# <AxesSubplot: >
